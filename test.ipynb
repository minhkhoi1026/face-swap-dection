# %%
"""source: https://github.com/ondyari/FaceForensics + https://github.com/ipazc/mtcnn"""
import os
import cv2
from tqdm import tqdm
from mtcnn import MTCNN
import tensorflow as tf

detector = MTCNN()

def extract_faces(image, output_path, prefix):
    img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    with tf.device('/GPU:0'):
        faces = detector.detect_faces(img)
    crop_face = 0
    for id, face in enumerate(faces):
        x, y, w, h = face['box']
        crop_face = cv2.cvtColor(img[y:y+h, x:x+w], cv2.COLOR_BGR2RGB)
        cv2.imwrite(os.path.join(output_path, '{}_{:02d}.png'.format(prefix, id)), crop_face)

def extract_frames(data_path, output_path, prefix_images, method='cv2'):
    """Method to extract frames, either with ffmpeg or opencv."""
    os.makedirs(output_path, exist_ok=True)
    reader = cv2.VideoCapture(data_path)
    frame_num = 0
    while reader.isOpened():
        success, image = reader.read()
        if not success:
            break
        prefix_face_img = '{}_{:04d}'.format(prefix_images, frame_num)
        extract_faces(image, output_path, prefix_face_img) # extract faces from single image
        frame_num += 1
    reader.release()
    
def extract_individual(individual_path, output_path, individual_name):
    """Extracts all videos file structure"""
    for video in os.listdir(individual_path):
        # prefix of image file name
        video_name = os.path.splitext(video)[0]
        prefix = f"{individual_name}_{video_name}"
        
        # folder for store image base on type of image 
        # image have name 1, 2 or HR_1 are real, others are fake
        image_type = "real" if video_name in ["1", "2", "HR_1"] else "fake"
        print(video_name)
        image_path = os.path.join(output_path, image_type)
        
        extract_frames(os.path.join(individual_path, video),
                       image_path, prefix)

def extract_all_individual(data_path, output_path):
    for individual in tqdm(os.listdir(data_path)):
        extract_individual(os.path.join(data_path, individual), output_path, individual)

tf.debugging.set_log_device_placement(True)

extract_all_individual(os.path.join("dataset", "casia_fasd", "test_release"), "test")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# 1
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
#   0%|          | 0/30 [00:13<?, ?it/s]
# c:\Users\minhk\miniconda3\envs\cv\lib\site-packages\mtcnn\mtcnn.py:206: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if method is 'Min':
# c:\Users\minhk\miniconda3\envs\cv\lib\site-packages\mtcnn\mtcnn.py:206: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if method is 'Min':
# c:\Users\minhk\miniconda3\envs\cv\lib\site-packages\mtcnn\mtcnn.py:206: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if method is 'Min':
# c:\Users\minhk\miniconda3\envs\cv\lib\site-packages\mtcnn\mtcnn.py:206: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if method is 'Min':
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\research\face_spoofing_detection\Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection\test.ipynb Cell 1 in <cell line: 56>()
#      <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=51'>52</a>         extract_individual(os.path.join(data_path, individual), output_path, individual)
#      <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=53'>54</a> tf.debugging.set_log_device_placement(True)
# ---> <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=55'>56</a> extract_all_individual(os.path.join("dataset", "casia_fasd", "test_release"), "test")
#
# e:\research\face_spoofing_detection\Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection\test.ipynb Cell 1 in extract_all_individual(data_path, output_path)
#      <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=49'>50</a> def extract_all_individual(data_path, output_path):
#      <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=50'>51</a>     for individual in tqdm(os.listdir(data_path)):
# ---> <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=51'>52</a>         extract_individual(os.path.join(data_path, individual), output_path, individual)
#
# e:\research\face_spoofing_detection\Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection\test.ipynb Cell 1 in extract_individual(individual_path, output_path, individual_name)
#      <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=43'>44</a> print(video_name)
#      <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=44'>45</a> image_path = os.path.join(output_path, image_type)
# ---> <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=46'>47</a> extract_frames(os.path.join(individual_path, video),
#      <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=47'>48</a>                image_path, prefix)
#
# e:\research\face_spoofing_detection\Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection\test.ipynb Cell 1 in extract_frames(data_path, output_path, prefix_images, method)
#      <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=27'>28</a>         break
#      <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=28'>29</a>     prefix_face_img = '{}_{:04d}'.format(prefix_images, frame_num)
# ---> <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=29'>30</a>     extract_faces(image, output_path, prefix_face_img) # extract faces from single image
#      <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=30'>31</a>     frame_num += 1
#      <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=31'>32</a> reader.release()
#
# e:\research\face_spoofing_detection\Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection\test.ipynb Cell 1 in extract_faces(image, output_path, prefix)
#      <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=10'>11</a> img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#      <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=11'>12</a> with tf.device('/GPU:0'):
# ---> <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=12'>13</a>     faces = detector.detect_faces(img)
#      <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=13'>14</a> crop_face = 0
#      <a href='vscode-notebook-cell:/e%3A/research/face_spoofing_detection/Attention-Based-Two-Stream-Convolutional-Networks-for-Face-Spoofing-Detection/test.ipynb#ch0000000?line=14'>15</a> for id, face in enumerate(faces):
#
# File c:\Users\minhk\miniconda3\envs\cv\lib\site-packages\mtcnn\mtcnn.py:300, in MTCNN.detect_faces(self, img)
#     298 # We pipe here each of the stages
#     299 for stage in stages:
# --> 300     result = stage(img, result[0], result[1])
#     302 [total_boxes, points] = result
#     304 bounding_boxes = []
#
# File c:\Users\minhk\miniconda3\envs\cv\lib\site-packages\mtcnn\mtcnn.py:342, in MTCNN.__stage1(self, image, scales, stage_status)
#     339 img_x = np.expand_dims(scaled_image, 0)
#     340 img_y = np.transpose(img_x, (0, 2, 1, 3))
# --> 342 out = self._pnet.predict(img_y)
#     344 out0 = np.transpose(out[0], (0, 2, 1, 3))
#     345 out1 = np.transpose(out[1], (0, 2, 1, 3))
#
# File c:\Users\minhk\miniconda3\envs\cv\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\minhk\miniconda3\envs\cv\lib\site-packages\keras\engine\training.py:2029, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2027 callbacks.on_predict_begin()
#    2028 batch_outputs = None
# -> 2029 for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    2030   with data_handler.catch_stop_iteration():
#    2031     for step in data_handler.steps():
#
# File c:\Users\minhk\miniconda3\envs\cv\lib\site-packages\keras\engine\data_adapter.py:1193, in DataHandler.enumerate_epochs(self)
#    1191 """Yields `(epoch, tf.data.Iterator)`."""
#    1192 with self._truncate_execution_to_epoch():
# -> 1193   data_iterator = iter(self._dataset)
#    1194   for epoch in range(self._initial_epoch, self._epochs):
#    1195     if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File c:\Users\minhk\miniconda3\envs\cv\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:494, in DatasetV2.__iter__(self)
#     492 if context.executing_eagerly() or ops.inside_function():
#     493   with ops.colocate_with(self._variant_tensor):
# --> 494     return iterator_ops.OwnedIterator(self)
#     495 else:
#     496   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     497                      "iteration in eager mode or within tf.function.")
#
# File c:\Users\minhk\miniconda3\envs\cv\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:696, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     692   if (components is not None or element_spec is not None):
#     693     raise ValueError(
#     694         "When `dataset` is provided, `element_spec` and `components` must "
#     695         "not be specified.")
# --> 696   self._create_iterator(dataset)
#     698 self._get_next_call_count = 0
#
# File c:\Users\minhk\miniconda3\envs\cv\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:721, in OwnedIterator._create_iterator(self, dataset)
#     716 with ops.colocate_with(ds_variant):
#     717   self._iterator_resource = (
#     718       gen_dataset_ops.anonymous_iterator_v3(
#     719           output_types=self._flat_output_types,
#     720           output_shapes=self._flat_output_shapes))
# --> 721   gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File c:\Users\minhk\miniconda3\envs\cv\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3408, in make_iterator(dataset, iterator, name)
#    3406 if tld.is_eager:
#    3407   try:
# -> 3408     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3409       _ctx, "MakeIterator", name, dataset, iterator)
#    3410     return _result
#    3411   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# Given one input image:
# 1. Use MTCNN for face and landmark detection
# 2. Align detected faces using affine transformation to size $128 \times 128$
# 3. If in training mode, apply data augmentation including horizontal flipping, random rotation ($0$-$20$ degree), and random crop ($114 \times 114$).
# 4. Generate MSR (multiscale retinex) image from RGB image
#
# Training params:
# - Momentum: $0.9$
# - Learning rate: $10^{-14}$
# - Batch size: $128$
# - Number of epoch to converge: $50$
